# %% [markdown]
# # STEP 1: Data Integration
# In this notebook we integrate all datasets into one unique datasets to facilitate the analysis.

# %%
#import libraries
import pandas as pd

# %% [markdown]
# ### 1. Read countries_population.csv file
# The file contains the population of different countries from years 2000 to 2019.

# %%
df_countries_population = pd.read_csv('INPUT DATA/countries_population.csv')
df_countries_population.head()
# Out:
#          Series Name  Series Code    Country Name Country Code 1990 [YR1990]  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG      12412308
# 1  Population, total  SP.POP.TOTL         Albania          ALB       3286542
# 2  Population, total  SP.POP.TOTL         Algeria          DZA      25758869
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM         47347
# 4  Population, total  SP.POP.TOTL         Andorra          AND         54509
#
#   2000 [YR2000] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013]  \
# 0      20779953      29185507      30117413      31161376      32269589
# 1       3089027       2913021       2905195       2900401       2895092
# 2      31042235      35977455      36661444      37383887      38140132
# 3         57821         56079         55759         55667         55713
# 4         65390         84449         83747         82427         80774
#
# ...

# %% [markdown]
# ### 2. Read countries_continent.csv file
# It contains basic information of the countries (continent, code…)

# %%
df_countries_continent = pd.read_csv('INPUT DATA/countries_continent.csv', encoding = "utf-8")
df_countries_continent = df_countries_continent.rename({'country_code': 'num_code'}, axis=1)
df_countries_continent = df_countries_continent.rename({'code_3': 'country_code'}, axis=1)
df_countries_continent.head()
# Out:
#           country code_2 country_code  num_code     iso_3166_2 continent  \
# 0     Afghanistan     AF          AFG         4  ISO 3166-2:AF      Asia
# 1   Åland Islands     AX          ALA       248  ISO 3166-2:AX    Europe
# 2         Albania     AL          ALB         8  ISO 3166-2:AL    Europe
# 3         Algeria     DZ          DZA        12  ISO 3166-2:DZ    Africa
# 4  American Samoa     AS          ASM        16  ISO 3166-2:AS   Oceania
#
#         sub_region  region_code  sub_region_code
# 0    Southern Asia        142.0             34.0
# 1  Northern Europe        150.0            154.0
# 2  Southern Europe        150.0             39.0
# 3  Northern Africa          2.0             15.0
# 4        Polynesia          9.0             61.0

# %% [markdown]
# ### 3. Read countries_deathrate.csv file
# The file contains the deathrates of different countries from years 2010 to 2019.

# %%
df_countries_deathrate = pd.read_csv('INPUT DATA/countries_deathrate.csv', encoding = "utf-8")
df_countries_deathrate.head()
# Out:
#                             Series Name     Series Code    Country Name  \
# 0  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN     Afghanistan
# 1  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN         Albania
# 2  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN         Algeria
# 3  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN  American Samoa
# 4  Death rate, crude (per 1,000 people)  SP.DYN.CDRT.IN         Andorra
#
#   Country Code 1990 [YR1990] 2000 [YR2000] 2010 [YR2010] 2011 [YR2011]  \
# 0          AFG        15.241        11.718          8.25         7.936
# 1          ALB         5.985         5.914         6.841         6.915
# 2          DZA         6.207         4.961         4.656          4.67
# 3          ASM            ..            ..            ..            ..
# 4          AND            ..            ..           2.8            ..
#
#   2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# ...

# %% [markdown]
# ### 4. Read countries_gdp.csv
# It contains the gross domestic product (GDP) value of different countries.

# %%
df_countries_gdp = pd.read_csv('INPUT DATA/countries_gdp.csv', error_bad_lines=False)
df_countries_gdp.head()
# Out:
# b'Skipping line 23: expected 65 fields, saw 66\nSkipping line 43: expected 65 fields, saw 66\nSkipping line 44: expected 65 fields, saw 66\nSkipping line 67: expected 65 fields, saw 66\nSkipping line 79: expected 65 fields, saw 66\nSkipping line 86: expected 65 fields, saw 66\nSkipping line 96: expected 65 fields, saw 66\nSkipping line 112: expected 65 fields, saw 66\nSkipping line 126: expected 65 fields, saw 66\nSkipping line 146: expected 65 fields, saw 66\nSkipping line 193: expected 65 fields, saw 66\nSkipping line 254: expected 65 fields, saw 66\nSkipping line 262: expected 65 fields, saw 66\n'
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2       Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3      Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# ...

# %% [markdown]
# ### 5. Read active_HIV_cases_children.csv file
# The file contains the active HIV cases of children (under 15 years) in different countries from years 1990 to 2018.

# %%
df_active_HIV_cases_children = pd.read_csv('INPUT DATA/active_HIV_cases_children.csv', error_bad_lines=False)
df_active_HIV_cases_children.head()
# Out:
#                Country   1990 1990_lower  1990_upper   1991 1991_lower  \
# 0          Afghanistan  <100       <100         <100  <100       <100
# 1              Albania   ...        ...          ...   ...        ...
# 2              Algeria  <100       <100         <100  <100       <100
# 3               Angola  1200      <1000         1900  1600       1000
# 4  Antigua and Barbuda  <100       <100         <100  <100       <100
#
#    1991_upper   1992 1992_lower  1992_upper  ...  2015_upper     2016  \
# 0        <100  <100       <100         <100  ...        <500    <500
# 1         ...   ...        ...          ...  ...         ...     ...
# 2        <100  <100       <100         <100  ...        <500    <500
# 3        2400  2100       1400         3100  ...      42 000  36 000
# 4        <100  <100       <100         <100  ...        <100    <100
#
#   2016_lower  2016_upper     2017 2017_lower  2017_upper     2018 2018_lower  \
# ...

# %% [markdown]
# ### 6. Read active_HIV_cases_male_adults.csv file
# It contains active HIV cases of male adults from the different countries from years 1990 to 2018.

# %%
df_active_HIV_cases_male_adults = pd.read_csv('INPUT DATA/active_HIV_cases_male_adults.csv', error_bad_lines=False)
df_active_HIV_cases_male_adults.head()
# Out:
#                Country   1990 1990_lower  1990_upper   1991 1991_lower  \
# 0          Afghanistan  <500       <200        <1000  <500       <200
# 1              Albania   ...        ...          ...   ...        ...
# 2              Algeria  <500       <500         <500  <500       <500
# 3               Angola  5500       3600         8700  6700       4500
# 4  Antigua and Barbuda  <100       <100         <100  <100       <100
#
#    1991_upper   1992 1992_lower  1992_upper  ...  2015_upper     2016  \
# 0       <1000  <500       <500         1100  ...        6100    4300
# 1         ...   ...        ...          ...  ...         ...     ...
# 2        <500  <500       <500        <1000  ...        7300    7200
# 3      10 000  8100       5700       12 000  ...      96 000  84 000
# 4        <100  <100       <100         <200  ...       <1000    <500
#
#   2016_lower  2016_upper     2017 2017_lower  2017_upper     2018 2018_lower  \
# ...

# %% [markdown]
# ### 7. Read active_HIV_cases_female_adults.csv file
# It contains active HIV cases of female adults from the different countries from years 1990 to 2018.

# %%
df_active_HIV_cases_female_adults = pd.read_csv('INPUT DATA/active_HIV_cases_female_adults.csv', error_bad_lines=False)
df_active_HIV_cases_female_adults.head()
# Out:
#                Country   1990 1990_lower  1990_upper   1991 1991_lower  \
# 0          Afghanistan  <200       <100         <500  <200       <100
# 1              Albania   ...        ...          ...   ...        ...
# 2              Algeria  <100       <100         <100  <100       <100
# 3               Angola  7400       4800       11 000  9700       6500
# 4  Antigua and Barbuda  <100       <100         <100  <100       <100
#
#    1991_upper     1992 1992_lower  1992_upper  ...  2015_upper      2016  \
# 0        <500    <200       <100         <500  ...        2400     1800
# 1         ...     ...        ...          ...  ...         ...      ...
# 2        <100    <200       <200         <200  ...        5800     6000
# 3      14 000  12 000       8700       18 000  ...     210 000  190 000
# 4        <100    <100       <100         <100  ...        <500     <500
#
#   2016_lower  2016_upper      2017 2017_lower  2017_upper      2018  \
# ...

# %% [markdown]
# ### 8. Read aids_deaths_children.csv file
# It contains active AIDS deaths of childrens from the different countries from years 1990 to 2018.

# %%
df_aids_deaths_children = pd.read_csv('INPUT DATA/aids_deaths_children.csv', error_bad_lines=False)
df_aids_deaths_children.head()
# Out:
#                Country   1990 1990_lower  1990_upper   1991 1991_lower  \
# 0          Afghanistan  <100       <100         <100  <100       <100
# 1              Albania   ...        ...          ...   ...        ...
# 2              Algeria  <100       <100         <100  <100       <100
# 3               Angola  <500       <200         <500  <500       <500
# 4  Antigua and Barbuda  <100       <100         <100  <100       <100
#
#    1991_upper   1992 1992_lower  1992_upper  ...  2015_upper   2016  \
# 0        <100  <100       <100         <100  ...        <100  <100
# 1         ...   ...        ...          ...  ...         ...   ...
# 2        <100  <100       <100         <100  ...        <100  <100
# 3       <1000  <500       <500        <1000  ...        5600  4500
# 4        <100  <100       <100         <100  ...        <100  <100
#
#   2016_lower  2016_upper   2017 2017_lower  2017_upper   2018 2018_lower  \
# ...

# %% [markdown]
# ### 9. Read aids_deaths_male_adults.csv file
# It contains active AIDS deaths of male adults from the different countries from years 1990 to 2018.

# %%
df_aids_deaths_male_adults = pd.read_csv('INPUT DATA/aids_deaths_male_adults.csv', error_bad_lines=False)
df_aids_deaths_male_adults.head()
# Out:
#                Country   1990 1990_lower  1990_upper   1991 1991_lower  \
# 0          Afghanistan  <100       <100         <100  <100       <100
# 1              Albania   ...        ...          ...   ...        ...
# 2              Algeria  <100       <100         <100  <100       <100
# 3               Angola  <200       <100         <500  <200       <200
# 4  Antigua and Barbuda  <100       <100         <100  <100       <100
#
#    1991_upper   1992 1992_lower  1992_upper  ...  2015_upper   2016  \
# 0        <100  <100       <100         <100  ...        <500  <500
# 1         ...   ...        ...          ...  ...         ...   ...
# 2        <100  <100       <100         <100  ...        <100  <100
# 3        <500  <500       <200         <500  ...        3100  2200
# 4        <100  <100       <100         <100  ...        <100  <100
#
#   2016_lower  2016_upper   2017 2017_lower  2017_upper   2018 2018_lower  \
# ...

# %% [markdown]
# ### 10. Read aids_deaths_female_adults.csv file
# It contains active AIDS deaths of female adults from the different countries from years 1990 to 2018.

# %%
df_aids_deaths_female_adults = pd.read_csv('INPUT DATA/aids_deaths_female_adults.csv', error_bad_lines=False)
df_aids_deaths_female_adults.head()
# Out:
#                Country   1990 1990_lower  1990_upper   1991 1991_lower  \
# 0          Afghanistan  <100       <100         <100  <100       <100
# 1              Albania   ...        ...          ...   ...        ...
# 2              Algeria  <100       <100         <100  <100       <100
# 3               Angola  <200       <100         <500  <200       <100
# 4  Antigua and Barbuda  <100       <100         <100  <100       <100
#
#    1991_upper   1992 1992_lower  1992_upper  ...  2015_upper   2016  \
# 0        <100  <100       <100         <100  ...        <200  <100
# 1         ...   ...        ...          ...  ...         ...   ...
# 2        <100  <100       <100         <100  ...        <100  <100
# 3        <500  <500       <200         <500  ...        4900  3700
# 4        <100  <100       <100         <100  ...        <100  <100
#
#   2016_lower  2016_upper   2017 2017_lower  2017_upper   2018 2018_lower  \
# ...

# %% [markdown]
# ### 11. Join the datasets

# %% [markdown]
# #### Join the countries with the corresponding codes

# %%
#get countries from datasets
countries = df_countries_population['Country Name']
codes = df_countries_population['Country Code']
df_countries = pd.concat([countries,codes], axis=1)
df_countries.columns = ['country_name','country_code']
df_countries.head()
# Out:
#      country_name country_code
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND

# %%
#join the countries, country code and other info
df_countries = df_countries.merge(df_countries_continent, on='country_code', how='left')
#remove inncesary columns
df_countries = df_countries.drop(columns=['country','code_2','num_code','iso_3166_2','region_code','sub_region_code'])
df_countries.head()
# Out:
#      country_name country_code continent       sub_region
# 0     Afghanistan          AFG      Asia    Southern Asia
# 1         Albania          ALB    Europe  Southern Europe
# 2         Algeria          DZA    Africa  Northern Africa
# 3  American Samoa          ASM   Oceania        Polynesia
# 4         Andorra          AND    Europe  Southern Europe

# %% [markdown]
# #### Join the population of each country from years 2010 to 2018
